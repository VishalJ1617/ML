# %%
import pandas as pd
from pmdarima.arima import auto_arima
import matplotlib.pyplot as plt
from math import sqrt

# %%
air_df=pd.read_csv('AirPassengers.csv',index_col=0)

# %%
air_df
# Out:
#          Passengers
# Month
# 1949-01         112
# 1949-02         118
# 1949-03         132
# 1949-04         129
# 1949-05         121
# ...             ...
# 1960-08         606
# 1960-09         508
# 1960-10         461
# 1960-11         390
# 1960-12         432
#
# [144 rows x 1 columns]

# %%
air_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 144 entries, 1949-01 to 1960-12
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Passengers  144 non-null    int64
# dtypes: int64(1)
# memory usage: 2.2+ KB

# %%
air_df.index=pd.to_datetime(air_df.index)

# %%
air_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 144 entries, 1949-01-01 to 1960-12-01
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Passengers  144 non-null    int64
# dtypes: int64(1)
# memory usage: 2.2 KB

# %%
y=air_df['Passengers']

# %%
y_train=y[:-12]
y_test=y[-12:]

# %%
y_train.plot(color='blue',label='train')
y_test.plot(color='pink',label='test')
plt.show()

# %%
from pmdarima.arima import auto_arima
model = auto_arima(y_train, trace=True,
                   error_action='ignore', 
                   suppress_warnings=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1218.683, Time=0.24 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1277.589, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1268.313, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1264.738, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1276.259, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.19 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.25 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.33 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1258.440, Time=0.11 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.30 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.35 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=1225.563, Time=0.16 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0] intercept
# Total fit time: 2.469 seconds

# %%
model = auto_arima(y_train, trace=True, error_action='ignore', 
                  suppress_warnings=True,seasonal=True,m=12)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=inf, Time=1.18 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=1022.234, Time=0.02 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=906.857, Time=0.27 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=963.555, Time=0.26 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=1192.711, Time=0.02 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=907.180, Time=0.08 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=908.543, Time=0.61 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=0.70 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=907.120, Time=0.23 sec
#  ARIMA(1,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=1.66 sec
#  ARIMA(0,0,0)(1,1,0)[12] intercept   : AIC=1021.611, Time=0.21 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=906.396, Time=0.38 sec
#  ARIMA(2,0,0)(0,1,0)[12] intercept   : AIC=906.075, Time=0.13 sec
#  ARIMA(2,0,0)(0,1,1)[12] intercept   : AIC=906.713, Time=0.29 sec
#  ARIMA(2,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=0.56 sec
#  ARIMA(3,0,0)(0,1,0)[12] intercept   : AIC=905.686, Time=0.12 sec
#  ARIMA(3,0,0)(1,1,0)[12] intercept   : AIC=906.124, Time=0.45 sec
#  ARIMA(3,0,0)(0,1,1)[12] intercept   : AIC=906.388, Time=0.34 sec
#  ARIMA(3,0,0)(1,1,1)[12] intercept   : AIC=906.035, Time=0.79 sec
#  ARIMA(4,0,0)(0,1,0)[12] intercept   : AIC=907.453, Time=0.21 sec
#  ARIMA(3,0,1)(0,1,0)[12] intercept   : AIC=907.583, Time=0.24 sec
#  ARIMA(2,0,1)(0,1,0)[12] intercept   : AIC=906.399, Time=0.20 sec
#  ARIMA(4,0,1)(0,1,0)[12] intercept   : AIC=909.320, Time=0.41 sec
#  ARIMA(3,0,0)(0,1,0)[12]             : AIC=911.907, Time=0.09 sec
#
# Best model:  ARIMA(3,0,0)(0,1,0)[12] intercept
# Total fit time: 9.490 seconds

# %%
forecast = model.predict(n_periods=len(y_test))
forecast = pd.DataFrame(forecast,index = y_test.index,
                        columns=['Prediction'])

# %%
plt.plot(y_train, label='Train',color="blue")
plt.plot(y_test, label='Valid',color="pink")
plt.plot(forecast, label='Prediction',color="purple")
plt.legend(loc='best')
plt.show()

# %%
#plotting the result
plt.plot(y_test)
plt.plot(forecast, color='red')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
rms = sqrt(mean_squared_error(y_test, forecast))
print('Test RMSE: %.3f' % rms)
# Out:
# Test RMSE: 18.536

# %%
#Building the data on the whole data

# %%
model = auto_arima(y, trace=True, error_action='ignore', 
                   suppress_warnings=True,m=12)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=1020.048, Time=0.85 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=1031.508, Time=0.03 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=1020.393, Time=0.09 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=1021.003, Time=0.14 sec
#  ARIMA(2,1,2)(0,1,1)[12]             : AIC=1019.935, Time=0.54 sec
#  ARIMA(2,1,2)(0,1,0)[12]             : AIC=1019.290, Time=0.19 sec
#  ARIMA(2,1,2)(1,1,0)[12]             : AIC=1019.546, Time=0.49 sec
#  ARIMA(1,1,2)(0,1,0)[12]             : AIC=1024.160, Time=0.10 sec
#  ARIMA(2,1,1)(0,1,0)[12]             : AIC=1017.847, Time=0.22 sec
#  ARIMA(2,1,1)(1,1,0)[12]             : AIC=1017.914, Time=0.42 sec
#  ARIMA(2,1,1)(0,1,1)[12]             : AIC=1018.359, Time=0.41 sec
#  ARIMA(2,1,1)(1,1,1)[12]             : AIC=1018.248, Time=0.78 sec
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=1022.393, Time=0.08 sec
#  ARIMA(2,1,0)(0,1,0)[12]             : AIC=1022.393, Time=0.07 sec
#  ARIMA(3,1,1)(0,1,0)[12]             : AIC=1019.084, Time=0.22 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=1020.393, Time=0.05 sec
#  ARIMA(3,1,0)(0,1,0)[12]             : AIC=1023.666, Time=0.09 sec
#  ARIMA(3,1,2)(0,1,0)[12]             : AIC=1021.083, Time=0.36 sec
#  ARIMA(2,1,1)(0,1,0)[12] intercept   : AIC=inf, Time=0.42 sec
#
# Best model:  ARIMA(2,1,1)(0,1,0)[12]
# Total fit time: 5.567 seconds

# %%
import numpy as np
forecast = model.predict(n_periods=12)
# forecast = pd.DataFrame(forecast,index = np.arange(y.shape[0]+1,y.shape[0]+7),
#                         columns=['Prediction'])
forecast
# Out:
# 1961-01-01    445.635869
# 1961-02-01    420.396491
# 1961-03-01    449.200322
# 1961-04-01    491.842355
# 1961-05-01    503.397223
# 1961-06-01    566.865475
# 1961-07-01    654.263428
# 1961-08-01    638.600928
# 1961-09-01    540.887336
# 1961-10-01    494.130341
# 1961-11-01    423.336533
# 1961-12-01    465.511486
# Freq: MS, dtype: float64

# %%
#plot the predictions for validation set
plt.plot(y, label='Train',color="pink")
plt.plot(forecast, label='Prediction',color="blue")
plt.show()
