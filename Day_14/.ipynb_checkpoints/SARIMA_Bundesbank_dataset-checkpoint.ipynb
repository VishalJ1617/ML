# %%
import pandas as pd
from pmdarima.arima import auto_arima
import matplotlib.pyplot as plt
from math import sqrt

# %%
bank_df=pd.read_csv('BUNDESBANK-BBK01_WT5511.csv',index_col=0)

# %%
bank_df
# Out:
#               Value
# Date
# 30-04-1968    39.10
# 31-05-1968    42.00
# 30-06-1968    40.95
# 31-07-1968    38.90
# 31-08-1968    39.85
# ...             ...
# 31-12-2015  1062.25
# 31-01-2016  1112.90
# 29-02-2016  1234.15
# 31-03-2016  1233.60
# 30-04-2016  1237.70
#
# [577 rows x 1 columns]

# %%
bank_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 577 entries, 30-04-1968 to 30-04-2016
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Value   577 non-null    float64
# dtypes: float64(1)
# memory usage: 9.0+ KB

# %%
bank_df.index=pd.to_datetime(bank_df.index)
# Out:
# /tmp/ipykernel_4931/2269622755.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   bank_df.index=pd.to_datetime(bank_df.index)

# %%
bank_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 577 entries, 1968-04-30 to 2016-04-30
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Value   577 non-null    float64
# dtypes: float64(1)
# memory usage: 9.0 KB

# %%
y=bank_df['Value']

# %%
y_train=y[:-6]
y_test=y[-6:]

# %%
y_train.plot(color='blue',label='train')
y_test.plot(color='pink',label='test')
plt.show()

# %%
from pmdarima.arima import auto_arima
model = auto_arima(y_train, trace=True,
                   error_action='ignore', 
                   suppress_warnings=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=1.54 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=5685.919, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=5681.456, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=5680.751, Time=0.19 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=5685.643, Time=0.04 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=5682.083, Time=0.18 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=5681.760, Time=0.31 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=5683.409, Time=0.47 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=5680.967, Time=0.08 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0] intercept
# Total fit time: 3.055 seconds

# %%
model = auto_arima(y_train, trace=True, error_action='ignore', 
                  suppress_warnings=True,seasonal=True,m=12)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=2.58 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=5685.919, Time=0.06 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=5682.975, Time=0.22 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=5682.375, Time=0.58 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=5685.643, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=5680.751, Time=0.21 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=5682.347, Time=0.51 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=5683.125, Time=0.87 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=5682.083, Time=0.18 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=5681.760, Time=0.30 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=5681.456, Time=0.08 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=5683.409, Time=0.53 sec
#  ARIMA(0,1,1)(0,0,0)[12]             : AIC=5680.967, Time=0.08 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[12] intercept
# Total fit time: 6.367 seconds

# %%
forecast = model.predict(n_periods=len(y_test))
forecast = pd.DataFrame(forecast,index = y_test.index,
                        columns=['Prediction'])

# %%
plt.plot(y_train, label='Train',color="blue")
plt.plot(y_test, label='Valid',color="pink")
plt.plot(forecast, label='Prediction',color="purple")
plt.legend(loc='best')
plt.show()

# %%
#plotting the result
plt.plot(y_test)
plt.plot(forecast, color='red')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
rms = sqrt(mean_squared_error(y_test, forecast))
print('Test RMSE: %.3f' % rms)
# Out:
# Test RMSE: 78.204

# %%
#Building the data on the whole data

# %%
model = auto_arima(y, trace=True, error_action='ignore', 
                   suppress_warnings=True,m=12)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=5748.652, Time=2.29 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=5759.940, Time=0.06 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=5757.601, Time=0.38 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=5757.111, Time=0.53 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=5759.885, Time=0.07 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=5750.100, Time=2.09 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=5749.817, Time=2.28 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=5750.382, Time=4.78 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=5750.400, Time=4.54 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=5750.249, Time=0.92 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=5750.426, Time=4.28 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=5750.929, Time=3.91 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=5752.500, Time=5.00 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=5758.790, Time=2.24 sec
#  ARIMA(2,1,1)(1,0,1)[12] intercept   : AIC=5758.757, Time=2.01 sec
#  ARIMA(3,1,2)(1,0,1)[12] intercept   : AIC=5747.616, Time=2.96 sec
#  ARIMA(3,1,2)(0,0,1)[12] intercept   : AIC=5747.751, Time=2.40 sec
#  ARIMA(3,1,2)(1,0,0)[12] intercept   : AIC=5747.615, Time=2.82 sec
#  ARIMA(3,1,2)(0,0,0)[12] intercept   : AIC=5745.887, Time=1.23 sec
#  ARIMA(3,1,1)(0,0,0)[12] intercept   : AIC=5760.322, Time=0.53 sec
#  ARIMA(4,1,2)(0,0,0)[12] intercept   : AIC=5744.489, Time=1.19 sec
#  ARIMA(4,1,2)(1,0,0)[12] intercept   : AIC=5746.455, Time=2.89 sec
#  ARIMA(4,1,2)(0,0,1)[12] intercept   : AIC=5746.823, Time=2.42 sec
#  ARIMA(4,1,2)(1,0,1)[12] intercept   : AIC=5747.371, Time=3.64 sec
#  ARIMA(4,1,1)(0,0,0)[12] intercept   : AIC=5761.411, Time=0.60 sec
#  ARIMA(5,1,2)(0,0,0)[12] intercept   : AIC=5741.794, Time=1.99 sec
#  ARIMA(5,1,2)(1,0,0)[12] intercept   : AIC=5742.110, Time=3.08 sec
#  ARIMA(5,1,2)(0,0,1)[12] intercept   : AIC=5742.344, Time=1.90 sec
#  ARIMA(5,1,2)(1,0,1)[12] intercept   : AIC=5741.148, Time=3.55 sec
#  ARIMA(5,1,2)(2,0,1)[12] intercept   : AIC=5742.695, Time=6.41 sec
#  ARIMA(5,1,2)(1,0,2)[12] intercept   : AIC=5742.696, Time=5.83 sec
#  ARIMA(5,1,2)(0,0,2)[12] intercept   : AIC=5742.339, Time=5.19 sec
#  ARIMA(5,1,2)(2,0,0)[12] intercept   : AIC=5741.906, Time=5.81 sec
#  ARIMA(5,1,2)(2,0,2)[12] intercept   : AIC=5744.786, Time=7.13 sec
#  ARIMA(5,1,1)(1,0,1)[12] intercept   : AIC=5749.134, Time=3.41 sec
#  ARIMA(5,1,3)(1,0,1)[12] intercept   : AIC=5738.518, Time=3.92 sec
#  ARIMA(5,1,3)(0,0,1)[12] intercept   : AIC=5739.418, Time=3.15 sec
#  ARIMA(5,1,3)(1,0,0)[12] intercept   : AIC=5738.964, Time=3.25 sec
#  ARIMA(5,1,3)(2,0,1)[12] intercept   : AIC=5740.359, Time=7.06 sec
#  ARIMA(5,1,3)(1,0,2)[12] intercept   : AIC=5739.998, Time=7.03 sec
#  ARIMA(5,1,3)(0,0,0)[12] intercept   : AIC=5738.043, Time=2.04 sec
#  ARIMA(4,1,3)(0,0,0)[12] intercept   : AIC=5745.501, Time=1.34 sec
#  ARIMA(5,1,4)(0,0,0)[12] intercept   : AIC=inf, Time=2.19 sec
#  ARIMA(4,1,4)(0,0,0)[12] intercept   : AIC=5744.595, Time=1.72 sec
#  ARIMA(5,1,3)(0,0,0)[12]             : AIC=5737.014, Time=0.92 sec
#  ARIMA(5,1,3)(1,0,0)[12]             : AIC=5737.796, Time=2.04 sec
#  ARIMA(5,1,3)(0,0,1)[12]             : AIC=5737.962, Time=2.07 sec
#  ARIMA(5,1,3)(1,0,1)[12]             : AIC=5736.791, Time=2.58 sec
#  ARIMA(5,1,3)(2,0,1)[12]             : AIC=5738.236, Time=4.96 sec
#  ARIMA(5,1,3)(1,0,2)[12]             : AIC=5738.220, Time=4.25 sec
#  ARIMA(5,1,3)(0,0,2)[12]             : AIC=5737.967, Time=3.31 sec
#  ARIMA(5,1,3)(2,0,0)[12]             : AIC=5737.598, Time=4.00 sec
#  ARIMA(5,1,3)(2,0,2)[12]             : AIC=5740.319, Time=5.33 sec
#  ARIMA(4,1,3)(1,0,1)[12]             : AIC=5746.834, Time=2.55 sec
#  ARIMA(5,1,2)(1,0,1)[12]             : AIC=5741.291, Time=2.35 sec
#  ARIMA(5,1,4)(1,0,1)[12]             : AIC=inf, Time=3.39 sec
#  ARIMA(4,1,2)(1,0,1)[12]             : AIC=5746.647, Time=2.26 sec
#  ARIMA(4,1,4)(1,0,1)[12]             : AIC=inf, Time=3.03 sec
#
# Best model:  ARIMA(5,1,3)(1,0,1)[12]
# Total fit time: 175.158 seconds

# %%
import numpy as np
forecast = model.predict(n_periods=6)
# forecast = pd.DataFrame(forecast,index = np.arange(y.shape[0]+1,y.shape[0]+7),
#                         columns=['Prediction'])
forecast
# Out:
# 2016-05-31    1209.936044
# 2016-06-30    1200.569523
# 2016-07-31    1231.486020
# 2016-08-31    1260.168201
# 2016-09-30    1254.914020
# 2016-10-31    1231.953200
# Freq: M, dtype: float64

# %%
#plot the predictions for validation set
plt.plot(y, label='Train',color="pink")
plt.plot(forecast, label='Prediction',color="blue")
plt.show()
