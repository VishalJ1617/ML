# %%
import pandas as pd
import matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori,association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
housing=pd.read_csv("Housing.csv")
housing
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 0     42000.0     5850         3        1        2      yes      no      yes
# 1     38500.0     4000         2        1        1      yes      no       no
# 2     49500.0     3060         3        1        1      yes      no       no
# 3     60500.0     6650         3        1        2      yes     yes       no
# 4     61000.0     6360         2        1        1      yes      no       no
# ..        ...      ...       ...      ...      ...      ...     ...      ...
# 541   91500.0     4800         3        2        4      yes     yes       no
# 542   94000.0     6000         3        2        4      yes      no       no
# 543  103000.0     6000         3        2        4      yes     yes       no
# 544  105000.0     6000         3        2        2      yes     yes       no
# 545  105000.0     6000         3        1        2      yes      no       no
#
#     gashw airco  garagepl prefarea
# 0      no    no         1       no
# 1      no    no         0       no
# 2      no    no         0       no
# 3      no    no         0       no
# 4      no    no         0       no
# ..    ...   ...       ...      ...
# 541    no   yes         0       no
# 542    no   yes         0       no
# 543    no   yes         1       no
# 544    no   yes         1       no
# 545    no   yes         1       no
#
# [546 rows x 12 columns]

# %%
housing['price'].describe()
# Out:
# count       546.000000
# mean      68121.597070
# std       26702.670926
# min       25000.000000
# 25%       49125.000000
# 50%       62000.000000
# 75%       82000.000000
# max      190000.000000
# Name: price, dtype: float64

# %%
intervals=[(0,50000),(50000,100000),(100000,150000),(150000,200000)]
bins=pd.IntervalIndex.from_tuples(intervals)
bins
# Out:
# IntervalIndex([(0, 50000], (50000, 100000], (100000, 150000], (150000, 200000]], dtype='interval[int64, right]')

# %%
housing['price_slab']=pd.cut(housing['price'],bins=bins)
housing
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 0     42000.0     5850         3        1        2      yes      no      yes
# 1     38500.0     4000         2        1        1      yes      no       no
# 2     49500.0     3060         3        1        1      yes      no       no
# 3     60500.0     6650         3        1        2      yes     yes       no
# 4     61000.0     6360         2        1        1      yes      no       no
# ..        ...      ...       ...      ...      ...      ...     ...      ...
# 541   91500.0     4800         3        2        4      yes     yes       no
# 542   94000.0     6000         3        2        4      yes      no       no
# 543  103000.0     6000         3        2        4      yes     yes       no
# 544  105000.0     6000         3        2        2      yes     yes       no
# 545  105000.0     6000         3        1        2      yes      no       no
#
#     gashw airco  garagepl prefarea        price_slab
# 0      no    no         1       no        (0, 50000]
# 1      no    no         0       no        (0, 50000]
# 2      no    no         0       no        (0, 50000]
# 3      no    no         0       no   (50000, 100000]
# 4      no    no         0       no   (50000, 100000]
# ..    ...   ...       ...      ...               ...
# 541    no   yes         0       no   (50000, 100000]
# 542    no   yes         0       no   (50000, 100000]
# 543    no   yes         1       no  (100000, 150000]
# 544    no   yes         1       no  (100000, 150000]
# 545    no   yes         1       no  (100000, 150000]
#
# [546 rows x 13 columns]

# %%
intervals=[(0,5000),(5000,10000),(10000,15000),(15000,20000)]
bins=pd.IntervalIndex.from_tuples(intervals)
housing['lotsize_slab']=pd.cut(housing['lotsize'],bins)
housing
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 0     42000.0     5850         3        1        2      yes      no      yes
# 1     38500.0     4000         2        1        1      yes      no       no
# 2     49500.0     3060         3        1        1      yes      no       no
# 3     60500.0     6650         3        1        2      yes     yes       no
# 4     61000.0     6360         2        1        1      yes      no       no
# ..        ...      ...       ...      ...      ...      ...     ...      ...
# 541   91500.0     4800         3        2        4      yes     yes       no
# 542   94000.0     6000         3        2        4      yes      no       no
# 543  103000.0     6000         3        2        4      yes     yes       no
# 544  105000.0     6000         3        2        2      yes     yes       no
# 545  105000.0     6000         3        1        2      yes      no       no
#
#     gashw airco  garagepl prefarea        price_slab   lotsize_slab
# 0      no    no         1       no        (0, 50000]  (5000, 10000]
# 1      no    no         0       no        (0, 50000]      (0, 5000]
# 2      no    no         0       no        (0, 50000]      (0, 5000]
# 3      no    no         0       no   (50000, 100000]  (5000, 10000]
# 4      no    no         0       no   (50000, 100000]  (5000, 10000]
# ..    ...   ...       ...      ...               ...            ...
# 541    no   yes         0       no   (50000, 100000]      (0, 5000]
# 542    no   yes         0       no   (50000, 100000]  (5000, 10000]
# 543    no   yes         1       no  (100000, 150000]  (5000, 10000]
# 544    no   yes         1       no  (100000, 150000]  (5000, 10000]
# 545    no   yes         1       no  (100000, 150000]  (5000, 10000]
#
# [546 rows x 14 columns]

# %%
housing.drop(['price','lotsize'],axis=1,inplace=True)
housing=housing.astype(object)
housing
# Out:
#     bedrooms bathrms stories driveway recroom fullbase gashw airco garagepl  \
# 0          3       1       2      yes      no      yes    no    no        1
# 1          2       1       1      yes      no       no    no    no        0
# 2          3       1       1      yes      no       no    no    no        0
# 3          3       1       2      yes     yes       no    no    no        0
# 4          2       1       1      yes      no       no    no    no        0
# ..       ...     ...     ...      ...     ...      ...   ...   ...      ...
# 541        3       2       4      yes     yes       no    no   yes        0
# 542        3       2       4      yes      no       no    no   yes        0
# 543        3       2       4      yes     yes       no    no   yes        1
# 544        3       2       2      yes     yes       no    no   yes        1
# 545        3       1       2      yes      no       no    no   yes        1
#
#     prefarea        price_slab   lotsize_slab
# 0         no        (0, 50000]  (5000, 10000]
# 1         no        (0, 50000]      (0, 5000]
# 2         no        (0, 50000]      (0, 5000]
# 3         no   (50000, 100000]  (5000, 10000]
# 4         no   (50000, 100000]  (5000, 10000]
# ..       ...               ...            ...
# 541       no   (50000, 100000]      (0, 5000]
# 542       no   (50000, 100000]  (5000, 10000]
# 543       no  (100000, 150000]  (5000, 10000]
# 544       no  (100000, 150000]  (5000, 10000]
# 545       no  (100000, 150000]  (5000, 10000]
#
# [546 rows x 12 columns]

# %%
fp_df=pd.get_dummies(housing,prefix_sep='=')
fp_df
# Out:
#      bedrooms=1  bedrooms=2  bedrooms=3  bedrooms=4  bedrooms=5  bedrooms=6  \
# 0         False       False        True       False       False       False
# 1         False        True       False       False       False       False
# 2         False       False        True       False       False       False
# 3         False       False        True       False       False       False
# 4         False        True       False       False       False       False
# ..          ...         ...         ...         ...         ...         ...
# 541       False       False        True       False       False       False
# 542       False       False        True       False       False       False
# 543       False       False        True       False       False       False
# 544       False       False        True       False       False       False
# 545       False       False        True       False       False       False
#
#      bathrms=1  bathrms=2  bathrms=3  bathrms=4  ...  prefarea=no  \
# 0         True      False      False      False  ...         True
# 1         True      False      False      False  ...         True
# 2         True      False      False      False  ...         True
# 3         True      False      False      False  ...         True
# 4         True      False      False      False  ...         True
# ..         ...        ...        ...        ...  ...          ...
# 541      False       True      False      False  ...         True
# 542      False       True      False      False  ...         True
# 543      False       True      False      False  ...         True
# 544      False       True      False      False  ...         True
# 545       True      False      False      False  ...         True
#
#      prefarea=yes  price_slab=(0, 50000]  price_slab=(50000, 100000]  \
# 0           False                   True                       False
# 1           False                   True                       False
# 2           False                   True                       False
# 3           False                  False                        True
# 4           False                  False                        True
# ..            ...                    ...                         ...
# 541         False                  False                        True
# 542         False                  False                        True
# 543         False                  False                       False
# 544         False                  False                       False
# 545         False                  False                       False
#
#      price_slab=(100000, 150000]  price_slab=(150000, 200000]  \
# 0                          False                        False
# 1                          False                        False
# 2                          False                        False
# 3                          False                        False
# 4                          False                        False
# ..                           ...                          ...
# 541                        False                        False
# 542                        False                        False
# 543                         True                        False
# 544                         True                        False
# 545                         True                        False
#
#      lotsize_slab=(0, 5000]  lotsize_slab=(5000, 10000]  \
# 0                     False                        True
# 1                      True                       False
# 2                      True                       False
# 3                     False                        True
# 4                     False                        True
# ..                      ...                         ...
# 541                    True                       False
# 542                   False                        True
# 543                   False                        True
# 544                   False                        True
# 545                   False                        True
#
#      lotsize_slab=(10000, 15000]  lotsize_slab=(15000, 20000]
# 0                          False                        False
# 1                          False                        False
# 2                          False                        False
# 3                          False                        False
# 4                          False                        False
# ..                           ...                          ...
# 541                        False                        False
# 542                        False                        False
# 543                        False                        False
# 544                        False                        False
# 545                        False                        False
#
# [546 rows x 38 columns]

# %%
itemsets=apriori(fp_df,min_support=0.2,use_colnames=True)
rules=association_rules(itemsets,metric='confidence',min_threshold=0.6)
rules=rules[['antecedents','consequents','support','confidence','lift']]
rules=rules[rules['lift']>1]
rules.sort_values(by='lift',ascending=False)
# Out:
#                                           antecedents  \
# 4505  (bathrms=1, prefarea=no, airco=no, fullbase=no)
# 4516                          (price_slab=(0, 50000])
# 147                            (bedrooms=2, gashw=no)
# 6718                          (price_slab=(0, 50000])
# 149                                      (bedrooms=2)
# ...                                               ...
# 518           (stories=2, price_slab=(50000, 100000])
# 688                                        (gashw=no)
# 687                         (recroom=no, fullbase=no)
# 1026                        (prefarea=no, bedrooms=3)
# 3253                 (bathrms=1, stories=1, gashw=no)
#
#                                             consequents   support  confidence  \
# 4505                            (price_slab=(0, 50000])  0.203297    0.609890
# 4516    (bathrms=1, prefarea=no, airco=no, fullbase=no)  0.203297    0.702532
# 147                                         (stories=1)  0.205128    0.854962
# 6718  (gashw=no, airco=no, bathrms=1, lotsize_slab=(...  0.201465    0.696203
# 149                               (stories=1, gashw=no)  0.205128    0.823529
# ...                                                 ...       ...         ...
# 518                                      (driveway=yes)  0.223443    0.859155
# 688                           (recroom=no, fullbase=no)  0.575092    0.602687
# 687                                          (gashw=no)  0.575092    0.954407
# 1026                              (bathrms=1, gashw=no)  0.276557    0.708920
# 3253                        (driveway=yes, prefarea=no)  0.219780    0.628272
#
#           lift
# 4505  2.107595
# 4516  2.107595
# 147   2.056428
# 6718  2.054738
# 149   2.043850
# ...        ...
# 518   1.000210
# 688   1.000204
# 687   1.000204
# 1026  1.000182
# 3253  1.000107
#
# [6544 rows x 5 columns]
